# %%
import pandas as pd
reviews=pd.read_csv('ign.csv')

# %%
reviews.head() 
# Print the first N row of data, the default value is 5
# Similarly, reviews.tail print the last N row of data, default value is 5
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews.shape
# Out:
# (18625, 11)

# %%
reviews.iloc[:5,:5]
# The iloc method allow us to retrieve rows and columns by position.
# The code above will retrieve the first 5 rows and first 5 columns data (from index 0 to index 4)
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita
# 2                          /games/splice/ipad-141070              iPad
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360
# 4                           /games/nhl-13/ps3-128181     PlayStation 3

# %% [markdown]
#  Big advantages of Pandas over just using Numpy is that pd allows to have columns with different data types.

# %%
reviews=reviews.iloc[:,1:]  # Remove the first column, which does not have any useful information.
reviews.head()
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# ...

# %%
reviews.loc[0:5,:]
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
# 5                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
#
# ...

# %%
some_reviews=reviews.iloc[10:20,]

# %%
some_reviews
# Out:
#                               title  \
# 10          Tekken Tag Tournament 2
# 11          Tekken Tag Tournament 2
# 12                       Wild Blood
# 13                Mark of the Ninja
# 14                Mark of the Ninja
# 15  Home: A Unique Horror Adventure
# 16  Home: A Unique Horror Adventure
# 17              Avengers Initiative
# 18             Way of the Samurai 4
# 19      JoJo's Bizarre Adventure HD
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14          /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
# 15  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
# ...

# %%
some_reviews.loc[12:17,'title']
# Out:
# 12                         Wild Blood
# 13                  Mark of the Ninja
# 14                  Mark of the Ninja
# 15    Home: A Unique Horror Adventure
# 16    Home: A Unique Horror Adventure
# 17                Avengers Initiative
# Name: title, dtype: object

# %% [markdown]
#  * Compare df.iloc and df.loc:
#
#  df.iloc: Retrieve data using location
#  df.loc:  Retrieve data using index

# %%
type(reviews['score'])
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([1,2,])
s1

#To create a Series, we pass a list or NumPy array into the Series object when we instantiate it.
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s2=pd.Series(['Boris Yeltsin','Mikhail Gorbachev'])
s2
# Out:
# 0        Boris Yeltsin
# 1    Mikhail Gorbachev
# dtype: object

# %%
reviews.mean(axis=1)

# The axis keyword argument is used to compute the mean of rach row or each column. Default: 0--> column. 1-->row.
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.500
# 13       509.250
# 14       509.250
# 15       508.375
# 16       508.375
# 17       508.500
# 18       507.375
# 19       507.750
# 20       507.750
# 21       514.625
# 22       514.625
# 23       514.625
# 24       515.000
# 25       514.250
# 26       514.750
# 27       514.125
# 28       514.250
# 29       513.625
#           ...
# 18595    510.850
# 18596    510.875
# 18597    510.225
# 18598    510.700
# 18599    510.750
# 18600    512.600
# 18601    512.600
# 18602    512.600
# 18603    512.450
# 18604    512.400
# 18605    511.500
# 18606    508.600
# 18607    510.750
# 18608    510.350
# 18609    510.750
# 18610    510.250
# 18611    508.700
# 18612    509.200
# 18613    508.000
# 18614    515.050
# 18615    515.050
# ...

# %%
reviews
# Out:
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# 5                              Total War Battles: Shogun
# 6                                    Double Dragon: Neon
# 7                                           Guild Wars 2
# 8                                    Double Dragon: Neon
# 9                              Total War Battles: Shogun
# 10                               Tekken Tag Tournament 2
# 11                               Tekken Tag Tournament 2
# 12                                            Wild Blood
# 13                                     Mark of the Ninja
# 14                                     Mark of the Ninja
# ...

# %%
reviews[(reviews['platform']=='Xbox One') & (reviews['score']>7)].head()

# Find games released for the Xbox One that have a score of more than 7.
# Out:
#                           title  \
# 17137                 Gone Home
# 17197            Rayman Legends
# 17295  LEGO Marvel Super Heroes
# 17313             Dead Rising 3
# 17317           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# 17295      Action              Y          2013             10           22
# ...

# %%
# %matplotlib inline

# %%
reviews[reviews['platform'] =='Xbox One']['score'].plot(kind='hist')
